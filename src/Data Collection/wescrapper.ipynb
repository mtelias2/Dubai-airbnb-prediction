# %%
#This is a rough work testing of the scrapper before implementation
#importing libraries needed 
import requests
from bs4 import BeautifulSoup
import csv
import re
import time
import datetime
import os
import urllib3
import selenium
import pandas as pd

# %%
link = "https://www.propertyfinder.ae/en/search?c=2&fu=0&l=1&ob=mr&page=1&rp=y"

# %%
web_page = requests.get(link)

# %%
#checking status code
web_page.status_code
# Out:
# 200

# %%
#checking content 
web_page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en"><head><script>\n      window.dataLayer = [];\n      window.loopaData = {};\n      // Default Tealium event data\n      window.tealium = {\n    \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0"page_country" \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0 : "ae",\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0        //Required\n    \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0"page_currency_code"  : "AED",\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0     //Required\n    \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0"page_lang" \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0 : "en",\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0        //Required\n    \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0"page_category" \xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0\xc2\xa0: "Ancillary Page",  /
# ...
